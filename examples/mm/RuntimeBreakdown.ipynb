# %%
from taucmdr.analysis.analyses.profile_barplot import ProfileBarPlotVisualizer
from taucmdr.model.trial import Trial
from taucmdr.cf.storage.levels import PROJECT_STORAGE
from taucmdr.data.tauprofile import TauProfile

def trials_to_patch_lists(trials, metric):
    from collections import defaultdict
    timers = set()
    sum_times = {}
    all_data = defaultdict(dict)
    for trial in trials:
        trial_num = trial['number']
        trial_data = trial.get_data()
        indices = TauProfile.indices(trial_data)
        sum_time = 0
        for n, c, t in indices:
            df = trial_data[n][c][t].interval_data()[[metric]].loc[trial_num, n, c, t]
            all_data[(trial_num, n, c, t)] = df
            for name, time in df.itertuples():
                timers.add(name)
            sum_time = sum_time + df.sum()
    categories = sorted(list(timers))
    xs = []
    ys = []
    print(all_data)
        
        
        
def show_runtime_breakdown(trials, metric):
    from taucmdr.gui.interaction import InteractivePlotHandler
    from taucmdr import logger
    from bokeh.plotting import figure
    from bokeh.models.glyphs import HBar
    from bokeh.io import output_notebook
    from bokeh.models import LabelSet

    logger.set_log_level('WARN')
    output_notebook(hide_banner=True)

    def build_runtime_breakdown(trials, metric):
        patch_lists = trials_to_patch_lists(trials, metric)
        fig = figure(plot_width=80, plot_height=40, output_backend="webgl", toolbar_location="right")
        return fig

    breakdown = build_runtime_breakdown(trials, metric)
    plot = InteractivePlotHandler(breakdown)
    plot.show()

show_runtime_breakdown([Trial.controller(PROJECT_STORAGE).search_hash("0a55be02ebaaa2ffcba5e80ad90662b4059883d5")[0],
                        Trial.controller(PROJECT_STORAGE).search_hash("91e392b88730cbc539555ef59f48d9f2d146c0e5")[0],
                        Trial.controller(PROJECT_STORAGE).search_hash("af0282a2f0603f9b96d106ca4ddda40082e6efa2")[0],
                        Trial.controller(PROJECT_STORAGE).search_hash("883c29fa41523f024578897f26aa98d9ccf93872")[0],
                        Trial.controller(PROJECT_STORAGE).search_hash("828374bf2d1549887554578766717531c5b9f091")[0],
                        Trial.controller(PROJECT_STORAGE).search_hash("061425ff2fca940c8918ebd325d95e522b659181")[0],
                        Trial.controller(PROJECT_STORAGE).search_hash("7284c749969c08de05d795b3ba334c2ff5075bb9")[0],
                        Trial.controller(PROJECT_STORAGE).search_hash("8629cf5864445aece7f16f53f7456dc5fcbf9f3d")[0]], "Exclusive")
# Out:
# {(7, 3, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       72.0
# .TAU application => int main(int, char **) C [{...      844.0
# .TAU application => int main(int, char **) C [{...    29970.0
# .TAU application => int main(int, char **) C [{...      240.0
# .TAU application => int main(int, char **) C [{...     2817.0
# .TAU application => int main(int, char **) C [{...  5471620.0
# .TAU application => int main(int, char **) C [{...    46321.0
# .TAU application => int main(int, char **) C [{...  3971843.0
# .TAU application => int main(int, char **) C [{...      142.0
# .TAU application => int main(int, char **) C [{...     5557.0
# MPI_Finalize()                                          844.0
# MPI_Init()                                            29970.0
# double **allocateMatrix(int, int) C [{matmult.c...     2817.0
# double do_work(void) C [{matmult.c} {132,1}-{16...      240.0
# double multiply(double, double) C [{matmult.c} ...    46321.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       72.0
# void compute(double **, double **, double **, i...  5471620.0
# void compute_interchange(double **, double **, ...  3971843.0
# void freeMatrix(double **, int, int) C [{matmul...      142.0
# void initialize(double **, int, int) C [{matmul...     5557.0, (5, 5, 0, 0):                                                     Exclusive
# .TAU application                                          7.0
# .TAU application => int main(int, char **) C [{...       93.0
# .TAU application => int main(int, char **) C [{...  1901455.0
# .TAU application => int main(int, char **) C [{...     7716.0
# .TAU application => int main(int, char **) C [{...      110.0
# .TAU application => int main(int, char **) C [{...     2015.0
# .TAU application => int main(int, char **) C [{...  4246053.0
# .TAU application => int main(int, char **) C [{...    43302.0
# .TAU application => int main(int, char **) C [{...  2506035.0
# .TAU application => int main(int, char **) C [{...      131.0
# .TAU application => int main(int, char **) C [{...     3100.0
# MPI_Finalize()                                      1901455.0
# MPI_Init()                                             7716.0
# double **allocateMatrix(int, int) C [{matmult.c...     2015.0
# double do_work(void) C [{matmult.c} {132,1}-{16...      110.0
# double multiply(double, double) C [{matmult.c} ...    43302.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       93.0
# void compute(double **, double **, double **, i...  4246053.0
# void compute_interchange(double **, double **, ...  2506035.0
# void freeMatrix(double **, int, int) C [{matmul...      131.0
# void initialize(double **, int, int) C [{matmul...     3100.0, (5, 0, 0, 0):                                                     Exclusive
# .TAU application                                          9.0
# .TAU application => int main(int, char **) C [{...       90.0
# .TAU application => int main(int, char **) C [{...  1269952.0
# .TAU application => int main(int, char **) C [{...     8614.0
# .TAU application => int main(int, char **) C [{...       86.0
# .TAU application => int main(int, char **) C [{...     2740.0
# .TAU application => int main(int, char **) C [{...  3956794.0
# .TAU application => int main(int, char **) C [{...    46133.0
# .TAU application => int main(int, char **) C [{...  3421620.0
# .TAU application => int main(int, char **) C [{...      157.0
# .TAU application => int main(int, char **) C [{...     3989.0
# MPI_Finalize()                                      1269952.0
# MPI_Init()                                             8614.0
# double **allocateMatrix(int, int) C [{matmult.c...     2740.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       86.0
# double multiply(double, double) C [{matmult.c} ...    46133.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       90.0
# void compute(double **, double **, double **, i...  3956794.0
# void compute_interchange(double **, double **, ...  3421620.0
# void freeMatrix(double **, int, int) C [{matmul...      157.0
# void initialize(double **, int, int) C [{matmul...     3989.0, (3, 1, 0, 0):                                                     Exclusive
# .TAU application                                          6.0
# .TAU application => int main(int, char **) C [{...       67.0
# .TAU application => int main(int, char **) C [{...    28708.0
# .TAU application => int main(int, char **) C [{...     3150.0
# .TAU application => int main(int, char **) C [{...       61.0
# .TAU application => int main(int, char **) C [{...     1424.0
# .TAU application => int main(int, char **) C [{...  2944844.0
# .TAU application => int main(int, char **) C [{...    23375.0
# .TAU application => int main(int, char **) C [{...  2220851.0
# .TAU application => int main(int, char **) C [{...      116.0
# .TAU application => int main(int, char **) C [{...     2409.0
# MPI_Finalize()                                        28708.0
# MPI_Init()                                             3150.0
# double **allocateMatrix(int, int) C [{matmult.c...     1424.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       61.0
# double multiply(double, double) C [{matmult.c} ...    23375.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       67.0
# void compute(double **, double **, double **, i...  2944844.0
# void compute_interchange(double **, double **, ...  2220851.0
# void freeMatrix(double **, int, int) C [{matmul...      116.0
# void initialize(double **, int, int) C [{matmul...     2409.0, (6, 6, 0, 0):                                                     Exclusive
# .TAU application                                          7.0
# .TAU application => int main(int, char **) C [{...       62.0
# .TAU application => int main(int, char **) C [{...   422324.0
# .TAU application => int main(int, char **) C [{...     7770.0
# .TAU application => int main(int, char **) C [{...       83.0
# .TAU application => int main(int, char **) C [{...     2657.0
# .TAU application => int main(int, char **) C [{...  4740950.0
# .TAU application => int main(int, char **) C [{...    45359.0
# .TAU application => int main(int, char **) C [{...  3902727.0
# .TAU application => int main(int, char **) C [{...      160.0
# .TAU application => int main(int, char **) C [{...     4208.0
# MPI_Finalize()                                       422324.0
# MPI_Init()                                             7770.0
# double **allocateMatrix(int, int) C [{matmult.c...     2657.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       83.0
# double multiply(double, double) C [{matmult.c} ...    45359.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       62.0
# void compute(double **, double **, double **, i...  4740950.0
# void compute_interchange(double **, double **, ...  3902727.0
# void freeMatrix(double **, int, int) C [{matmul...      160.0
# void initialize(double **, int, int) C [{matmul...     4208.0, (4, 1, 0, 0):                                                     Exclusive
# .TAU application                                          6.0
# .TAU application => int main(int, char **) C [{...       46.0
# .TAU application => int main(int, char **) C [{...  1475525.0
# .TAU application => int main(int, char **) C [{...     3816.0
# .TAU application => int main(int, char **) C [{...       80.0
# .TAU application => int main(int, char **) C [{...     1594.0
# .TAU application => int main(int, char **) C [{...  3539072.0
# .TAU application => int main(int, char **) C [{...    23442.0
# .TAU application => int main(int, char **) C [{...  2522670.0
# .TAU application => int main(int, char **) C [{...      185.0
# .TAU application => int main(int, char **) C [{...     2641.0
# MPI_Finalize()                                      1475525.0
# MPI_Init()                                             3816.0
# double **allocateMatrix(int, int) C [{matmult.c...     1594.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       80.0
# double multiply(double, double) C [{matmult.c} ...    23442.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       46.0
# void compute(double **, double **, double **, i...  3539072.0
# void compute_interchange(double **, double **, ...  2522670.0
# void freeMatrix(double **, int, int) C [{matmul...      185.0
# void initialize(double **, int, int) C [{matmul...     2641.0, (2, 0, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       61.0
# .TAU application => int main(int, char **) C [{...    19236.0
# .TAU application => int main(int, char **) C [{...     2906.0
# .TAU application => int main(int, char **) C [{...       58.0
# .TAU application => int main(int, char **) C [{...     1348.0
# .TAU application => int main(int, char **) C [{...  2508099.0
# .TAU application => int main(int, char **) C [{...    23324.0
# .TAU application => int main(int, char **) C [{...  2144484.0
# .TAU application => int main(int, char **) C [{...      124.0
# .TAU application => int main(int, char **) C [{...     1908.0
# MPI_Finalize()                                        19236.0
# MPI_Init()                                             2906.0
# double **allocateMatrix(int, int) C [{matmult.c...     1348.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       58.0
# double multiply(double, double) C [{matmult.c} ...    23324.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       61.0
# void compute(double **, double **, double **, i...  2508099.0
# void compute_interchange(double **, double **, ...  2144484.0
# void freeMatrix(double **, int, int) C [{matmul...      124.0
# void initialize(double **, int, int) C [{matmul...     1908.0, (7, 7, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       71.0
# .TAU application => int main(int, char **) C [{...   186883.0
# .TAU application => int main(int, char **) C [{...    29387.0
# .TAU application => int main(int, char **) C [{...       96.0
# .TAU application => int main(int, char **) C [{...     2695.0
# .TAU application => int main(int, char **) C [{...  5349739.0
# .TAU application => int main(int, char **) C [{...    46353.0
# .TAU application => int main(int, char **) C [{...  3908724.0
# .TAU application => int main(int, char **) C [{...      168.0
# .TAU application => int main(int, char **) C [{...     4832.0
# MPI_Finalize()                                       186883.0
# MPI_Init()                                            29387.0
# double **allocateMatrix(int, int) C [{matmult.c...     2695.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       96.0
# double multiply(double, double) C [{matmult.c} ...    46353.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       71.0
# void compute(double **, double **, double **, i...  5349739.0
# void compute_interchange(double **, double **, ...  3908724.0
# void freeMatrix(double **, int, int) C [{matmul...      168.0
# void initialize(double **, int, int) C [{matmul...     4832.0, (5, 4, 0, 0):                                                     Exclusive
# .TAU application                                          9.0
# .TAU application => int main(int, char **) C [{...       56.0
# .TAU application => int main(int, char **) C [{...   156279.0
# .TAU application => int main(int, char **) C [{...     8156.0
# .TAU application => int main(int, char **) C [{...       88.0
# .TAU application => int main(int, char **) C [{...     2603.0
# .TAU application => int main(int, char **) C [{...  5210815.0
# .TAU application => int main(int, char **) C [{...    46828.0
# .TAU application => int main(int, char **) C [{...  3281100.0
# .TAU application => int main(int, char **) C [{...      146.0
# .TAU application => int main(int, char **) C [{...     4069.0
# MPI_Finalize()                                       156279.0
# MPI_Init()                                             8156.0
# double **allocateMatrix(int, int) C [{matmult.c...     2603.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       88.0
# double multiply(double, double) C [{matmult.c} ...    46828.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       56.0
# void compute(double **, double **, double **, i...  5210815.0
# void compute_interchange(double **, double **, ...  3281100.0
# void freeMatrix(double **, int, int) C [{matmul...      146.0
# void initialize(double **, int, int) C [{matmul...     4069.0, (6, 5, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       57.0
# .TAU application => int main(int, char **) C [{...      620.0
# .TAU application => int main(int, char **) C [{...     7784.0
# .TAU application => int main(int, char **) C [{...       76.0
# .TAU application => int main(int, char **) C [{...     2667.0
# .TAU application => int main(int, char **) C [{...  5211861.0
# .TAU application => int main(int, char **) C [{...    28888.0
# .TAU application => int main(int, char **) C [{...  3869759.0
# .TAU application => int main(int, char **) C [{...      144.0
# .TAU application => int main(int, char **) C [{...     4150.0
# MPI_Finalize()                                          620.0
# MPI_Init()                                             7784.0
# double **allocateMatrix(int, int) C [{matmult.c...     2667.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       76.0
# double multiply(double, double) C [{matmult.c} ...    28888.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       57.0
# void compute(double **, double **, double **, i...  5211861.0
# void compute_interchange(double **, double **, ...  3869759.0
# void freeMatrix(double **, int, int) C [{matmul...      144.0
# void initialize(double **, int, int) C [{matmul...     4150.0, (6, 2, 0, 0):                                                     Exclusive
# .TAU application                                          9.0
# .TAU application => int main(int, char **) C [{...       61.0
# .TAU application => int main(int, char **) C [{...   694937.0
# .TAU application => int main(int, char **) C [{...     7908.0
# .TAU application => int main(int, char **) C [{...       75.0
# .TAU application => int main(int, char **) C [{...     2663.0
# .TAU application => int main(int, char **) C [{...  4866920.0
# .TAU application => int main(int, char **) C [{...    57874.0
# .TAU application => int main(int, char **) C [{...  3491019.0
# .TAU application => int main(int, char **) C [{...      170.0
# .TAU application => int main(int, char **) C [{...     4411.0
# MPI_Finalize()                                       694937.0
# MPI_Init()                                             7908.0
# double **allocateMatrix(int, int) C [{matmult.c...     2663.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       75.0
# double multiply(double, double) C [{matmult.c} ...    57874.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       61.0
# void compute(double **, double **, double **, i...  4866920.0
# void compute_interchange(double **, double **, ...  3491019.0
# void freeMatrix(double **, int, int) C [{matmul...      170.0
# void initialize(double **, int, int) C [{matmul...     4411.0, (3, 2, 0, 0):                                                     Exclusive
# .TAU application                                          6.0
# .TAU application => int main(int, char **) C [{...       42.0
# .TAU application => int main(int, char **) C [{...      639.0
# .TAU application => int main(int, char **) C [{...     3332.0
# .TAU application => int main(int, char **) C [{...       50.0
# .TAU application => int main(int, char **) C [{...     1458.0
# .TAU application => int main(int, char **) C [{...  2979531.0
# .TAU application => int main(int, char **) C [{...    33216.0
# .TAU application => int main(int, char **) C [{...  2204321.0
# .TAU application => int main(int, char **) C [{...      109.0
# .TAU application => int main(int, char **) C [{...     2410.0
# MPI_Finalize()                                          639.0
# MPI_Init()                                             3332.0
# double **allocateMatrix(int, int) C [{matmult.c...     1458.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       50.0
# double multiply(double, double) C [{matmult.c} ...    33216.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       42.0
# void compute(double **, double **, double **, i...  2979531.0
# void compute_interchange(double **, double **, ...  2204321.0
# void freeMatrix(double **, int, int) C [{matmul...      109.0
# void initialize(double **, int, int) C [{matmul...     2410.0, (7, 0, 0, 0):                                                     Exclusive
# .TAU application                                         11.0
# .TAU application => int main(int, char **) C [{...       64.0
# .TAU application => int main(int, char **) C [{...    25933.0
# .TAU application => int main(int, char **) C [{...    29997.0
# .TAU application => int main(int, char **) C [{...       78.0
# .TAU application => int main(int, char **) C [{...     2764.0
# .TAU application => int main(int, char **) C [{...  5473132.0
# .TAU application => int main(int, char **) C [{...    45011.0
# .TAU application => int main(int, char **) C [{...  3947394.0
# .TAU application => int main(int, char **) C [{...      149.0
# .TAU application => int main(int, char **) C [{...     4821.0
# MPI_Finalize()                                        25933.0
# MPI_Init()                                            29997.0
# double **allocateMatrix(int, int) C [{matmult.c...     2764.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       78.0
# double multiply(double, double) C [{matmult.c} ...    45011.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       64.0
# void compute(double **, double **, double **, i...  5473132.0
# void compute_interchange(double **, double **, ...  3947394.0
# void freeMatrix(double **, int, int) C [{matmul...      149.0
# void initialize(double **, int, int) C [{matmul...     4821.0, (5, 1, 0, 0):                                                     Exclusive
# .TAU application                                         10.0
# .TAU application => int main(int, char **) C [{...       59.0
# .TAU application => int main(int, char **) C [{...   428947.0
# .TAU application => int main(int, char **) C [{...     8488.0
# .TAU application => int main(int, char **) C [{...       83.0
# .TAU application => int main(int, char **) C [{...     2634.0
# .TAU application => int main(int, char **) C [{...  4770044.0
# .TAU application => int main(int, char **) C [{...    45890.0
# .TAU application => int main(int, char **) C [{...  3450035.0
# .TAU application => int main(int, char **) C [{...      156.0
# .TAU application => int main(int, char **) C [{...     4055.0
# MPI_Finalize()                                       428947.0
# MPI_Init()                                             8488.0
# double **allocateMatrix(int, int) C [{matmult.c...     2634.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       83.0
# double multiply(double, double) C [{matmult.c} ...    45890.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       59.0
# void compute(double **, double **, double **, i...  4770044.0
# void compute_interchange(double **, double **, ...  3450035.0
# void freeMatrix(double **, int, int) C [{matmul...      156.0
# void initialize(double **, int, int) C [{matmul...     4055.0, (6, 1, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       60.0
# .TAU application => int main(int, char **) C [{...   172002.0
# .TAU application => int main(int, char **) C [{...     7917.0
# .TAU application => int main(int, char **) C [{...      107.0
# .TAU application => int main(int, char **) C [{...     2622.0
# .TAU application => int main(int, char **) C [{...  4996763.0
# .TAU application => int main(int, char **) C [{...    49809.0
# .TAU application => int main(int, char **) C [{...  3892699.0
# .TAU application => int main(int, char **) C [{...      160.0
# .TAU application => int main(int, char **) C [{...     4251.0
# MPI_Finalize()                                       172002.0
# MPI_Init()                                             7917.0
# double **allocateMatrix(int, int) C [{matmult.c...     2622.0
# double do_work(void) C [{matmult.c} {132,1}-{16...      107.0
# double multiply(double, double) C [{matmult.c} ...    49809.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       60.0
# void compute(double **, double **, double **, i...  4996763.0
# void compute_interchange(double **, double **, ...  3892699.0
# void freeMatrix(double **, int, int) C [{matmul...      160.0
# void initialize(double **, int, int) C [{matmul...     4251.0, (4, 0, 0, 0):                                                     Exclusive
# .TAU application                                         11.0
# .TAU application => int main(int, char **) C [{...       73.0
# .TAU application => int main(int, char **) C [{...  1734545.0
# .TAU application => int main(int, char **) C [{...     4049.0
# .TAU application => int main(int, char **) C [{...       85.0
# .TAU application => int main(int, char **) C [{...     2553.0
# .TAU application => int main(int, char **) C [{...  3336716.0
# .TAU application => int main(int, char **) C [{...    51320.0
# .TAU application => int main(int, char **) C [{...  2436112.0
# .TAU application => int main(int, char **) C [{...      194.0
# .TAU application => int main(int, char **) C [{...     3284.0
# MPI_Finalize()                                      1734545.0
# MPI_Init()                                             4049.0
# double **allocateMatrix(int, int) C [{matmult.c...     2553.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       85.0
# double multiply(double, double) C [{matmult.c} ...    51320.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       73.0
# void compute(double **, double **, double **, i...  3336716.0
# void compute_interchange(double **, double **, ...  2436112.0
# void freeMatrix(double **, int, int) C [{matmul...      194.0
# void initialize(double **, int, int) C [{matmul...     3284.0, (7, 4, 0, 0):                                                     Exclusive
# .TAU application                                         10.0
# .TAU application => int main(int, char **) C [{...       78.0
# .TAU application => int main(int, char **) C [{...   186370.0
# .TAU application => int main(int, char **) C [{...    30062.0
# .TAU application => int main(int, char **) C [{...       78.0
# .TAU application => int main(int, char **) C [{...     2756.0
# .TAU application => int main(int, char **) C [{...  5366417.0
# .TAU application => int main(int, char **) C [{...    47286.0
# .TAU application => int main(int, char **) C [{...  3891247.0
# .TAU application => int main(int, char **) C [{...      157.0
# .TAU application => int main(int, char **) C [{...     4940.0
# MPI_Finalize()                                       186370.0
# MPI_Init()                                            30062.0
# double **allocateMatrix(int, int) C [{matmult.c...     2756.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       78.0
# double multiply(double, double) C [{matmult.c} ...    47286.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       78.0
# void compute(double **, double **, double **, i...  5366417.0
# void compute_interchange(double **, double **, ...  3891247.0
# void freeMatrix(double **, int, int) C [{matmul...      157.0
# void initialize(double **, int, int) C [{matmul...     4940.0, (3, 3, 0, 0):                                                     Exclusive
# .TAU application                                          6.0
# .TAU application => int main(int, char **) C [{...       57.0
# .TAU application => int main(int, char **) C [{...    23337.0
# .TAU application => int main(int, char **) C [{...     3163.0
# .TAU application => int main(int, char **) C [{...       65.0
# .TAU application => int main(int, char **) C [{...     1394.0
# .TAU application => int main(int, char **) C [{...  2972641.0
# .TAU application => int main(int, char **) C [{...    24116.0
# .TAU application => int main(int, char **) C [{...  2197702.0
# .TAU application => int main(int, char **) C [{...      115.0
# .TAU application => int main(int, char **) C [{...     2429.0
# MPI_Finalize()                                        23337.0
# MPI_Init()                                             3163.0
# double **allocateMatrix(int, int) C [{matmult.c...     1394.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       65.0
# double multiply(double, double) C [{matmult.c} ...    24116.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       57.0
# void compute(double **, double **, double **, i...  2972641.0
# void compute_interchange(double **, double **, ...  2197702.0
# void freeMatrix(double **, int, int) C [{matmul...      115.0
# void initialize(double **, int, int) C [{matmul...     2429.0, (1, 0, 0, 0):                                                     Exclusive
# .TAU application                                          9.0
# .TAU application => int main(int, char **) C [{...       60.0
# .TAU application => int main(int, char **) C [{...    47928.0
# .TAU application => int main(int, char **) C [{...     2817.0
# .TAU application => int main(int, char **) C [{...       57.0
# .TAU application => int main(int, char **) C [{...     1310.0
# .TAU application => int main(int, char **) C [{...  2260467.0
# .TAU application => int main(int, char **) C [{...    22585.0
# .TAU application => int main(int, char **) C [{...  2097564.0
# .TAU application => int main(int, char **) C [{...      115.0
# .TAU application => int main(int, char **) C [{...     1848.0
# MPI_Finalize()                                        47928.0
# MPI_Init()                                             2817.0
# double **allocateMatrix(int, int) C [{matmult.c...     1310.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       57.0
# double multiply(double, double) C [{matmult.c} ...    22585.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       60.0
# void compute(double **, double **, double **, i...  2260467.0
# void compute_interchange(double **, double **, ...  2097564.0
# void freeMatrix(double **, int, int) C [{matmul...      115.0
# void initialize(double **, int, int) C [{matmul...     1848.0, (6, 4, 0, 0):                                                     Exclusive
# .TAU application                                          9.0
# .TAU application => int main(int, char **) C [{...       56.0
# .TAU application => int main(int, char **) C [{...   665818.0
# .TAU application => int main(int, char **) C [{...     7756.0
# .TAU application => int main(int, char **) C [{...       84.0
# .TAU application => int main(int, char **) C [{...     2769.0
# .TAU application => int main(int, char **) C [{...  4629487.0
# .TAU application => int main(int, char **) C [{...    49395.0
# .TAU application => int main(int, char **) C [{...  3766691.0
# .TAU application => int main(int, char **) C [{...      169.0
# .TAU application => int main(int, char **) C [{...     4165.0
# MPI_Finalize()                                       665818.0
# MPI_Init()                                             7756.0
# double **allocateMatrix(int, int) C [{matmult.c...     2769.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       84.0
# double multiply(double, double) C [{matmult.c} ...    49395.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       56.0
# void compute(double **, double **, double **, i...  4629487.0
# void compute_interchange(double **, double **, ...  3766691.0
# void freeMatrix(double **, int, int) C [{matmul...      169.0
# void initialize(double **, int, int) C [{matmul...     4165.0, (4, 3, 0, 0):                                                     Exclusive
# .TAU application                                         11.0
# .TAU application => int main(int, char **) C [{...       56.0
# .TAU application => int main(int, char **) C [{...  1042531.0
# .TAU application => int main(int, char **) C [{...     3240.0
# .TAU application => int main(int, char **) C [{...       82.0
# .TAU application => int main(int, char **) C [{...     1529.0
# .TAU application => int main(int, char **) C [{...  4205418.0
# .TAU application => int main(int, char **) C [{...    44371.0
# .TAU application => int main(int, char **) C [{...  2268453.0
# .TAU application => int main(int, char **) C [{...      132.0
# .TAU application => int main(int, char **) C [{...     2793.0
# MPI_Finalize()                                      1042531.0
# MPI_Init()                                             3240.0
# double **allocateMatrix(int, int) C [{matmult.c...     1529.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       82.0
# double multiply(double, double) C [{matmult.c} ...    44371.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       56.0
# void compute(double **, double **, double **, i...  4205418.0
# void compute_interchange(double **, double **, ...  2268453.0
# void freeMatrix(double **, int, int) C [{matmul...      132.0
# void initialize(double **, int, int) C [{matmul...     2793.0, (4, 4, 0, 0):                                                     Exclusive
# .TAU application                                          6.0
# .TAU application => int main(int, char **) C [{...       64.0
# .TAU application => int main(int, char **) C [{...      590.0
# .TAU application => int main(int, char **) C [{...     3342.0
# .TAU application => int main(int, char **) C [{...       85.0
# .TAU application => int main(int, char **) C [{...     1533.0
# .TAU application => int main(int, char **) C [{...  3611384.0
# .TAU application => int main(int, char **) C [{...    24036.0
# .TAU application => int main(int, char **) C [{...  3924942.0
# .TAU application => int main(int, char **) C [{...      166.0
# .TAU application => int main(int, char **) C [{...     2665.0
# MPI_Finalize()                                          590.0
# MPI_Init()                                             3342.0
# double **allocateMatrix(int, int) C [{matmult.c...     1533.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       85.0
# double multiply(double, double) C [{matmult.c} ...    24036.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       64.0
# void compute(double **, double **, double **, i...  3611384.0
# void compute_interchange(double **, double **, ...  3924942.0
# void freeMatrix(double **, int, int) C [{matmul...      166.0
# void initialize(double **, int, int) C [{matmul...     2665.0, (7, 1, 0, 0):                                                     Exclusive
# .TAU application                                         11.0
# .TAU application => int main(int, char **) C [{...      510.0
# .TAU application => int main(int, char **) C [{...   111078.0
# .TAU application => int main(int, char **) C [{...    29601.0
# .TAU application => int main(int, char **) C [{...      109.0
# .TAU application => int main(int, char **) C [{...     2725.0
# .TAU application => int main(int, char **) C [{...  5388946.0
# .TAU application => int main(int, char **) C [{...    50201.0
# .TAU application => int main(int, char **) C [{...  3941289.0
# .TAU application => int main(int, char **) C [{...      157.0
# .TAU application => int main(int, char **) C [{...     4889.0
# MPI_Finalize()                                       111078.0
# MPI_Init()                                            29601.0
# double **allocateMatrix(int, int) C [{matmult.c...     2725.0
# double do_work(void) C [{matmult.c} {132,1}-{16...      109.0
# double multiply(double, double) C [{matmult.c} ...    50201.0
# int main(int, char **) C [{matmult.c} {209,1}-{...      510.0
# void compute(double **, double **, double **, i...  5388946.0
# void compute_interchange(double **, double **, ...  3941289.0
# void freeMatrix(double **, int, int) C [{matmul...      157.0
# void initialize(double **, int, int) C [{matmul...     4889.0, (5, 2, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       89.0
# .TAU application => int main(int, char **) C [{...      661.0
# .TAU application => int main(int, char **) C [{...     8577.0
# .TAU application => int main(int, char **) C [{...       82.0
# .TAU application => int main(int, char **) C [{...     2598.0
# .TAU application => int main(int, char **) C [{...  5166147.0
# .TAU application => int main(int, char **) C [{...    46858.0
# .TAU application => int main(int, char **) C [{...  3481147.0
# .TAU application => int main(int, char **) C [{...      171.0
# .TAU application => int main(int, char **) C [{...     4097.0
# MPI_Finalize()                                          661.0
# MPI_Init()                                             8577.0
# double **allocateMatrix(int, int) C [{matmult.c...     2598.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       82.0
# double multiply(double, double) C [{matmult.c} ...    46858.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       89.0
# void compute(double **, double **, double **, i...  5166147.0
# void compute_interchange(double **, double **, ...  3481147.0
# void freeMatrix(double **, int, int) C [{matmul...      171.0
# void initialize(double **, int, int) C [{matmul...     4097.0, (6, 0, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       83.0
# .TAU application => int main(int, char **) C [{...    53891.0
# .TAU application => int main(int, char **) C [{...     7567.0
# .TAU application => int main(int, char **) C [{...      101.0
# .TAU application => int main(int, char **) C [{...     1932.0
# .TAU application => int main(int, char **) C [{...  5105041.0
# .TAU application => int main(int, char **) C [{...    37818.0
# .TAU application => int main(int, char **) C [{...  3916917.0
# .TAU application => int main(int, char **) C [{...      151.0
# .TAU application => int main(int, char **) C [{...     2922.0
# MPI_Finalize()                                        53891.0
# MPI_Init()                                             7567.0
# double **allocateMatrix(int, int) C [{matmult.c...     1932.0
# double do_work(void) C [{matmult.c} {132,1}-{16...      101.0
# double multiply(double, double) C [{matmult.c} ...    37818.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       83.0
# void compute(double **, double **, double **, i...  5105041.0
# void compute_interchange(double **, double **, ...  3916917.0
# void freeMatrix(double **, int, int) C [{matmul...      151.0
# void initialize(double **, int, int) C [{matmul...     2922.0, (2, 2, 0, 0):                                                     Exclusive
# .TAU application                                          7.0
# .TAU application => int main(int, char **) C [{...       65.0
# .TAU application => int main(int, char **) C [{...     1017.0
# .TAU application => int main(int, char **) C [{...     2639.0
# .TAU application => int main(int, char **) C [{...       54.0
# .TAU application => int main(int, char **) C [{...     1385.0
# .TAU application => int main(int, char **) C [{...  2526525.0
# .TAU application => int main(int, char **) C [{...    23138.0
# .TAU application => int main(int, char **) C [{...  2144592.0
# .TAU application => int main(int, char **) C [{...      112.0
# .TAU application => int main(int, char **) C [{...     1913.0
# MPI_Finalize()                                         1017.0
# MPI_Init()                                             2639.0
# double **allocateMatrix(int, int) C [{matmult.c...     1385.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       54.0
# double multiply(double, double) C [{matmult.c} ...    23138.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       65.0
# void compute(double **, double **, double **, i...  2526525.0
# void compute_interchange(double **, double **, ...  2144592.0
# void freeMatrix(double **, int, int) C [{matmul...      112.0
# void initialize(double **, int, int) C [{matmul...     1913.0, (7, 2, 0, 0):                                                     Exclusive
# .TAU application                                         12.0
# .TAU application => int main(int, char **) C [{...       73.0
# .TAU application => int main(int, char **) C [{...     8074.0
# .TAU application => int main(int, char **) C [{...    30392.0
# .TAU application => int main(int, char **) C [{...       98.0
# .TAU application => int main(int, char **) C [{...     6391.0
# .TAU application => int main(int, char **) C [{...  5463623.0
# .TAU application => int main(int, char **) C [{...    44945.0
# .TAU application => int main(int, char **) C [{...  3972973.0
# .TAU application => int main(int, char **) C [{...      140.0
# .TAU application => int main(int, char **) C [{...     2994.0
# MPI_Finalize()                                         8074.0
# MPI_Init()                                            30392.0
# double **allocateMatrix(int, int) C [{matmult.c...     6391.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       98.0
# double multiply(double, double) C [{matmult.c} ...    44945.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       73.0
# void compute(double **, double **, double **, i...  5463623.0
# void compute_interchange(double **, double **, ...  3972973.0
# void freeMatrix(double **, int, int) C [{matmul...      140.0
# void initialize(double **, int, int) C [{matmul...     2994.0, (7, 5, 0, 0):                                                     Exclusive
# .TAU application                                         11.0
# .TAU application => int main(int, char **) C [{...       64.0
# .TAU application => int main(int, char **) C [{...   165363.0
# .TAU application => int main(int, char **) C [{...    29867.0
# .TAU application => int main(int, char **) C [{...       90.0
# .TAU application => int main(int, char **) C [{...     2571.0
# .TAU application => int main(int, char **) C [{...  5392624.0
# .TAU application => int main(int, char **) C [{...    49731.0
# .TAU application => int main(int, char **) C [{...  3884296.0
# .TAU application => int main(int, char **) C [{...      163.0
# .TAU application => int main(int, char **) C [{...     4532.0
# MPI_Finalize()                                       165363.0
# MPI_Init()                                            29867.0
# double **allocateMatrix(int, int) C [{matmult.c...     2571.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       90.0
# double multiply(double, double) C [{matmult.c} ...    49731.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       64.0
# void compute(double **, double **, double **, i...  5392624.0
# void compute_interchange(double **, double **, ...  3884296.0
# void freeMatrix(double **, int, int) C [{matmul...      163.0
# void initialize(double **, int, int) C [{matmul...     4532.0, (3, 0, 0, 0):                                                     Exclusive
# .TAU application                                         15.0
# .TAU application => int main(int, char **) C [{...       53.0
# .TAU application => int main(int, char **) C [{...    45400.0
# .TAU application => int main(int, char **) C [{...     3275.0
# .TAU application => int main(int, char **) C [{...       57.0
# .TAU application => int main(int, char **) C [{...     1424.0
# .TAU application => int main(int, char **) C [{...  2941966.0
# .TAU application => int main(int, char **) C [{...    23320.0
# .TAU application => int main(int, char **) C [{...  2206919.0
# .TAU application => int main(int, char **) C [{...      124.0
# .TAU application => int main(int, char **) C [{...     2432.0
# MPI_Finalize()                                        45400.0
# MPI_Init()                                             3275.0
# double **allocateMatrix(int, int) C [{matmult.c...     1424.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       57.0
# double multiply(double, double) C [{matmult.c} ...    23320.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       53.0
# void compute(double **, double **, double **, i...  2941966.0
# void compute_interchange(double **, double **, ...  2206919.0
# void freeMatrix(double **, int, int) C [{matmul...      124.0
# void initialize(double **, int, int) C [{matmul...     2432.0, (1, 1, 0, 0):                                                     Exclusive
# .TAU application                                          7.0
# .TAU application => int main(int, char **) C [{...       46.0
# .TAU application => int main(int, char **) C [{...      395.0
# .TAU application => int main(int, char **) C [{...     2823.0
# .TAU application => int main(int, char **) C [{...       48.0
# .TAU application => int main(int, char **) C [{...     1310.0
# .TAU application => int main(int, char **) C [{...  2285825.0
# .TAU application => int main(int, char **) C [{...    22584.0
# .TAU application => int main(int, char **) C [{...  2119682.0
# .TAU application => int main(int, char **) C [{...      107.0
# .TAU application => int main(int, char **) C [{...     1848.0
# MPI_Finalize()                                          395.0
# MPI_Init()                                             2823.0
# double **allocateMatrix(int, int) C [{matmult.c...     1310.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       48.0
# double multiply(double, double) C [{matmult.c} ...    22584.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       46.0
# void compute(double **, double **, double **, i...  2285825.0
# void compute_interchange(double **, double **, ...  2119682.0
# void freeMatrix(double **, int, int) C [{matmul...      107.0
# void initialize(double **, int, int) C [{matmul...     1848.0, (4, 2, 0, 0):                                                     Exclusive
# .TAU application                                          7.0
# .TAU application => int main(int, char **) C [{...       57.0
# .TAU application => int main(int, char **) C [{...   853164.0
# .TAU application => int main(int, char **) C [{...     4191.0
# .TAU application => int main(int, char **) C [{...       76.0
# .TAU application => int main(int, char **) C [{...     2559.0
# .TAU application => int main(int, char **) C [{...  3954121.0
# .TAU application => int main(int, char **) C [{...    46426.0
# .TAU application => int main(int, char **) C [{...  2705108.0
# .TAU application => int main(int, char **) C [{...      160.0
# .TAU application => int main(int, char **) C [{...     3305.0
# MPI_Finalize()                                       853164.0
# MPI_Init()                                             4191.0
# double **allocateMatrix(int, int) C [{matmult.c...     2559.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       76.0
# double multiply(double, double) C [{matmult.c} ...    46426.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       57.0
# void compute(double **, double **, double **, i...  3954121.0
# void compute_interchange(double **, double **, ...  2705108.0
# void freeMatrix(double **, int, int) C [{matmul...      160.0
# void initialize(double **, int, int) C [{matmul...     3305.0, (2, 1, 0, 0):                                                     Exclusive
# .TAU application                                          9.0
# .TAU application => int main(int, char **) C [{...       44.0
# .TAU application => int main(int, char **) C [{...      498.0
# .TAU application => int main(int, char **) C [{...     2917.0
# .TAU application => int main(int, char **) C [{...       47.0
# .TAU application => int main(int, char **) C [{...     1582.0
# .TAU application => int main(int, char **) C [{...  2517911.0
# .TAU application => int main(int, char **) C [{...    24195.0
# .TAU application => int main(int, char **) C [{...  2152372.0
# .TAU application => int main(int, char **) C [{...      111.0
# .TAU application => int main(int, char **) C [{...     1905.0
# MPI_Finalize()                                          498.0
# MPI_Init()                                             2917.0
# double **allocateMatrix(int, int) C [{matmult.c...     1582.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       47.0
# double multiply(double, double) C [{matmult.c} ...    24195.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       44.0
# void compute(double **, double **, double **, i...  2517911.0
# void compute_interchange(double **, double **, ...  2152372.0
# void freeMatrix(double **, int, int) C [{matmul...      111.0
# void initialize(double **, int, int) C [{matmul...     1905.0, (0, 0, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       60.0
# .TAU application => int main(int, char **) C [{...      318.0
# .TAU application => int main(int, char **) C [{...     2880.0
# .TAU application => int main(int, char **) C [{...       65.0
# .TAU application => int main(int, char **) C [{...     2163.0
# .TAU application => int main(int, char **) C [{...  2293036.0
# .TAU application => int main(int, char **) C [{...    43008.0
# .TAU application => int main(int, char **) C [{...  2108681.0
# .TAU application => int main(int, char **) C [{...      114.0
# .TAU application => int main(int, char **) C [{...     3236.0
# MPI_Finalize()                                          318.0
# MPI_Init()                                             2880.0
# double **allocateMatrix(int, int) C [{matmult.c...     2163.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       65.0
# double multiply(double, double) C [{matmult.c} ...    43008.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       60.0
# void compute(double **, double **, double **, i...  2293036.0
# void compute_interchange(double **, double **, ...  2108681.0
# void freeMatrix(double **, int, int) C [{matmul...      114.0
# void initialize(double **, int, int) C [{matmul...     3236.0, (7, 6, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       63.0
# .TAU application => int main(int, char **) C [{...   201860.0
# .TAU application => int main(int, char **) C [{...    29774.0
# .TAU application => int main(int, char **) C [{...       77.0
# .TAU application => int main(int, char **) C [{...     2789.0
# .TAU application => int main(int, char **) C [{...  5368969.0
# .TAU application => int main(int, char **) C [{...    51745.0
# .TAU application => int main(int, char **) C [{...  3869071.0
# .TAU application => int main(int, char **) C [{...      172.0
# .TAU application => int main(int, char **) C [{...     4685.0
# MPI_Finalize()                                       201860.0
# MPI_Init()                                            29774.0
# double **allocateMatrix(int, int) C [{matmult.c...     2789.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       77.0
# double multiply(double, double) C [{matmult.c} ...    51745.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       63.0
# void compute(double **, double **, double **, i...  5368969.0
# void compute_interchange(double **, double **, ...  3869071.0
# void freeMatrix(double **, int, int) C [{matmul...      172.0
# void initialize(double **, int, int) C [{matmul...     4685.0, (5, 3, 0, 0):                                                     Exclusive
# .TAU application                                          8.0
# .TAU application => int main(int, char **) C [{...       63.0
# .TAU application => int main(int, char **) C [{...  1509241.0
# .TAU application => int main(int, char **) C [{...     8120.0
# .TAU application => int main(int, char **) C [{...      136.0
# .TAU application => int main(int, char **) C [{...     2473.0
# .TAU application => int main(int, char **) C [{...  4707607.0
# .TAU application => int main(int, char **) C [{...    28445.0
# .TAU application => int main(int, char **) C [{...  2449948.0
# .TAU application => int main(int, char **) C [{...      123.0
# .TAU application => int main(int, char **) C [{...     3899.0
# MPI_Finalize()                                      1509241.0
# MPI_Init()                                             8120.0
# double **allocateMatrix(int, int) C [{matmult.c...     2473.0
# double do_work(void) C [{matmult.c} {132,1}-{16...      136.0
# double multiply(double, double) C [{matmult.c} ...    28445.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       63.0
# void compute(double **, double **, double **, i...  4707607.0
# void compute_interchange(double **, double **, ...  2449948.0
# void freeMatrix(double **, int, int) C [{matmul...      123.0
# void initialize(double **, int, int) C [{matmul...     3899.0, (6, 3, 0, 0):                                                     Exclusive
# .TAU application                                         10.0
# .TAU application => int main(int, char **) C [{...       54.0
# .TAU application => int main(int, char **) C [{...  1799271.0
# .TAU application => int main(int, char **) C [{...     8218.0
# .TAU application => int main(int, char **) C [{...       77.0
# .TAU application => int main(int, char **) C [{...     2679.0
# .TAU application => int main(int, char **) C [{...  4637059.0
# .TAU application => int main(int, char **) C [{...    50417.0
# .TAU application => int main(int, char **) C [{...  2624185.0
# .TAU application => int main(int, char **) C [{...      135.0
# .TAU application => int main(int, char **) C [{...     4163.0
# MPI_Finalize()                                      1799271.0
# MPI_Init()                                             8218.0
# double **allocateMatrix(int, int) C [{matmult.c...     2679.0
# double do_work(void) C [{matmult.c} {132,1}-{16...       77.0
# double multiply(double, double) C [{matmult.c} ...    50417.0
# int main(int, char **) C [{matmult.c} {209,1}-{...       54.0
# void compute(double **, double **, double **, i...  4637059.0
# void compute_interchange(double **, double **, ...  2624185.0
# void freeMatrix(double **, int, int) C [{matmul...      135.0
# void initialize(double **, int, int) C [{matmul...     4163.0}
# <script
#     src="http://localhost:56287/autoload.js?bokeh-autoload-element=8d2d1e30-abcb-4003-be5c-d2b10172cd3b&bokeh-app-path=/&bokeh-absolute-url=http://localhost:56287"
#     id="8d2d1e30-abcb-4003-be5c-d2b10172cd3b"
#     data-bokeh-model-id=""
#     data-bokeh-doc-id=""
# ></script>
# [TAU] *****************************************************************************************************************************************************************
# [TAU]
# [TAU] WARNING
# [TAU]
# [TAU] W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='3d79394e-734f-41b3-9262-f642998821ce', ...)
# [TAU]
# [TAU] *****************************************************************************************************************************************************************
